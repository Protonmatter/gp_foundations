# %% [markdown]
# # Kalman filtering and chaos utilities
#
# This notebook mirrors `docs/08_kalman_filter.md` and `docs/09_chaotic_dynamical_systems.md`.

# %%
import numpy as np
from gp_foundations.filters import KalmanFilter
from gp_foundations.systems import chaotic_timing_sequence

kf = KalmanFilter(
    transition_matrix=np.array([[1.0]]),
    observation_matrix=np.array([[1.0]]),
    process_covariance=np.array([[0.01]]),
    observation_covariance=np.array([[0.1]]),
    initial_state=np.array([0.0]),
    initial_covariance=np.array([[1.0]]),
)
kf.step(np.array([1.0]))
chaotic_timing_sequence(seed=7, length=5)
