# %% [markdown]
# # Acquisition functions and Bayesian optimization
#
# This notebook mirrors `docs/03_acquisition_functions.md`.

# %%
import numpy as np
from gp_foundations.acquisition import expected_improvement, upper_confidence_bound

mean = np.array([0.1, 0.4, 0.5])
std = np.array([0.2, 0.1, 0.3])
ucb = upper_confidence_bound(mean, std, beta=2.0)
ei = expected_improvement(mean, std, best=0.35)
ucb, ei
